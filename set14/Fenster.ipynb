# %%
import random
from tkinter import *
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
import matplotlib.pyplot as plt
import math
import numpy as np
from matplotlib.widgets import Slider
from tft_class import *
from tkinter import Toplevel, Label, Button, Frame , Canvas, PhotoImage
from PIL import Image, ImageTk
from collections import defaultdict
import copy
import os
import shared_data
import json
from TeamPlaner import TeamPlaner
from GameWindow import GameWindow

import sys


def start_game():
    gold = int(entry_gold.get())
    level = int(level_scale.get())
    stage = float(stage_scale.get())
    out_of_pool = out_pool_slider.get()
    champion_pool = create_champion_pool()
    
    odds = get_odds()
    champions_in_play = []
    
    global game, shop, bank, field, three_stared_list
    three_stared_list = []
    game = Game(gold, level, stage, champion_pool, odds, champions_in_play, three_stared_list = three_stared_list)
    if out_of_pool:
        champion_pool = game.remove_champs()
        game.champion_pool  = champion_pool
    field = Field(game_state = game, champion_pool = champion_pool, three_stared_list = game.three_stared_list)
    bank = Bank(game_state = game, field = field, champion_pool = champion_pool, three_stared_list = game.three_stared_list)
    shop = Shop(game_state = game, odds = odds, champion_pool = champion_pool, bank = bank, field = field, three_stared_list = game.three_stared_list)
    label_output.config(text=f"Game gestartet!\nLevel: {level}, Stage: {stage}, Gold: {gold}")
    GameWindow(root, game, shop, bank, field)


import tkinter as tk

# Tkinter-Hauptfenster
root = Tk()

# Level Slider (von 1 bis 10)
level_label = Label(root, text="Level:")
level_label.pack()
level_scale = Scale(root, from_=1, to=10, orient="horizontal")
level_scale.pack()

# Stage Slider (von 0.0 bis 10.0)
stage_label = Label(root, text="Stage:")
stage_label.pack()
stage_scale = Scale(root, from_=1.0, to=10.0, orient="horizontal", resolution=0.1)
stage_scale.pack()

# Gold
Label(root, text="Gold:").pack()
entry_gold = Entry(root)
entry_gold.pack()

# Champions aus dem Pool nehmen
out_pool_label = Label(root, text ="Wähle ja oder nein, wenn Champions aus dem Pool genommen werden sollen")
out_pool_slider = Scale(root, from_=0, to=1, orient="horizontal", length=50, showvalue=0)
out_pool_slider.config(label="Nein  Ja")
out_pool_label.pack()
out_pool_slider.pack()
# Start Knopf
start_label = Label(root, text = "Starte das Spiel!")
start_label.pack()
start_button = Button(root, text = "Start-Simulation!", command = start_game)
start_button.pack()

# Commands Interactive Simulation



# Output
label_output = Label(root, text="'Willkommen!", fg="blue")
label_output.pack()
# Tkinter-Event-Schleife starten
root.mainloop()
# Out:
# [<tkinter.Label object .!gamewindow.!label22>, <tkinter.Label object .!gamewindow.!label24>, <tkinter.Label object .!gamewindow.!label26>, <tkinter.Label object .!gamewindow.!label28>, <tkinter.Label object .!gamewindow.!label30>, <tkinter.Label object .!gamewindow.!label32>, <tkinter.Label object .!gamewindow.!label34>, <tkinter.Label object .!gamewindow.!label36>, <tkinter.Label object .!gamewindow.!label38>, <tkinter.Label object .!gamewindow.!label40>, <tkinter.Label object .!gamewindow.!label42>, <tkinter.Label object .!gamewindow.!label44>, <tkinter.Label object .!gamewindow.!label46>, <tkinter.Label object .!gamewindow.!label48>, <tkinter.Label object .!gamewindow.!label50>, <tkinter.Label object .!gamewindow.!label52>, <tkinter.Label object .!gamewindow.!label54>, <tkinter.Label object .!gamewindow.!label56>, <tkinter.Label object .!gamewindow.!label58>, <tkinter.Label object .!gamewindow.!label60>, <tkinter.Label object .!gamewindow.!label62>, <tkinter.Label object .!gamewindow.!label64>, <tkinter.Label object .!gamewindow.!label66>, <tkinter.Label object .!gamewindow.!label68>, <tkinter.Label object .!gamewindow.!label70>, <tkinter.Label object .!gamewindow.!label72>, <tkinter.Label object .!gamewindow.!label74>, <tkinter.Label object .!gamewindow.!label76>, <tkinter.Label object .!gamewindow.!label78>, <tkinter.Label object .!gamewindow.!label80>, <tkinter.Label object .!gamewindow.!label82>, <tkinter.Label object .!gamewindow.!label84>]
# Zufälliger Champion: Galio
# []
# False
# Galio wird zum Shop hinzugefügt.
# Zufälliger Champion: Vex
# []
# False
# Vex wird zum Shop hinzugefügt.
# Zufälliger Champion: Yuumi
# []
# False
# Yuumi wird zum Shop hinzugefügt.
# Zufälliger Champion: Varus
# []
# False
# Varus wird zum Shop hinzugefügt.
# Zufälliger Champion: Naafiri
# []
# False
# Naafiri wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Zeri
# []
# False
# Zeri wird zum Shop hinzugefügt.
# Zufälliger Champion: Senna
# []
# False
# Senna wird zum Shop hinzugefügt.
# Zufälliger Champion: Darius
# []
# False
# Darius wird zum Shop hinzugefügt.
# Zufälliger Champion: Yuumi
# []
# False
# Yuumi wird zum Shop hinzugefügt.
# Zufälliger Champion: Gragas
# []
# False
# Gragas wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Leona
# []
# False
# Leona wird zum Shop hinzugefügt.
# Zufälliger Champion: Jinx
# []
# False
# Jinx wird zum Shop hinzugefügt.
# Zufälliger Champion: Shyvana
# []
# False
# Shyvana wird zum Shop hinzugefügt.
# Zufälliger Champion: Kindred
# []
# False
# Kindred wird zum Shop hinzugefügt.
# Zufälliger Champion: Xayah
# []
# False
# Xayah wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Twisted Fate
# []
# False
# Twisted Fate wird zum Shop hinzugefügt.
# Zufälliger Champion: Jarvan IV
# []
# False
# Jarvan IV wird zum Shop hinzugefügt.
# Zufälliger Champion: Draven
# []
# False
# Draven wird zum Shop hinzugefügt.
# Zufälliger Champion: Xayah
# []
# False
# Xayah wird zum Shop hinzugefügt.
# Zufälliger Champion: Rengar
# []
# False
# Rengar wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Brand
# []
# False
# Brand wird zum Shop hinzugefügt.
# Zufälliger Champion: Aphelios
# []
# False
# Aphelios wird zum Shop hinzugefügt.
# Zufälliger Champion: Fiddlesticks
# []
# False
# Fiddlesticks wird zum Shop hinzugefügt.
# Zufälliger Champion: Sejuani
# []
# False
# Sejuani wird zum Shop hinzugefügt.
# Zufälliger Champion: Annie
# []
# False
# Annie wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Mordekaiser
# []
# False
# Mordekaiser wird zum Shop hinzugefügt.
# Zufälliger Champion: Fiddlesticks
# []
# False
# Fiddlesticks wird zum Shop hinzugefügt.
# Zufälliger Champion: Skarner
# []
# False
# Skarner wird zum Shop hinzugefügt.
# Zufälliger Champion: Brand
# []
# False
# Brand wird zum Shop hinzugefügt.
# Zufälliger Champion: Poppy
# []
# False
# Poppy wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Elise
# []
# False
# Elise wird zum Shop hinzugefügt.
# Zufälliger Champion: Rengar
# []
# False
# Rengar wird zum Shop hinzugefügt.
# Zufälliger Champion: Kindred
# []
# False
# Kindred wird zum Shop hinzugefügt.
# Zufälliger Champion: Viego
# []
# False
# Viego wird zum Shop hinzugefügt.
# Zufälliger Champion: Draven
# []
# False
# Draven wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Rhaast
# []
# False
# Rhaast wird zum Shop hinzugefügt.
# Zufälliger Champion: Naafiri
# []
# False
# Naafiri wird zum Shop hinzugefügt.
# Zufälliger Champion: Yuumi
# []
# False
# Yuumi wird zum Shop hinzugefügt.
# Zufälliger Champion: Zeri
# []
# False
# Zeri wird zum Shop hinzugefügt.
# Zufälliger Champion: Renekton
# []
# False
# Renekton wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Skarner
# []
# False
# Skarner wird zum Shop hinzugefügt.
# Zufälliger Champion: Xayah
# []
# False
# Xayah wird zum Shop hinzugefügt.
# Zufälliger Champion: Vayne
# []
# False
# Vayne wird zum Shop hinzugefügt.
# Zufälliger Champion: Alistar
# []
# False
# Alistar wird zum Shop hinzugefügt.
# Zufälliger Champion: Leblanc
# []
# False
# Leblanc wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Brand
# []
# False
# Brand wird zum Shop hinzugefügt.
# Zufälliger Champion: Annie
# []
# False
# Annie wird zum Shop hinzugefügt.
# Zufälliger Champion: Brand
# []
# False
# Brand wird zum Shop hinzugefügt.
# Zufälliger Champion: Vayne
# []
# False
# Vayne wird zum Shop hinzugefügt.
# Zufälliger Champion: Ekko
# []
# False
# Ekko wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Shaco
# []
# False
# Shaco wird zum Shop hinzugefügt.
# Zufälliger Champion: Leblanc
# []
# False
# Leblanc wird zum Shop hinzugefügt.
# Zufälliger Champion: Fiddlesticks
# []
# False
# Fiddlesticks wird zum Shop hinzugefügt.
# Zufälliger Champion: Kobuko
# []
# False
# Kobuko wird zum Shop hinzugefügt.
# Zufälliger Champion: Illaoi
# []
# False
# Illaoi wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Gragas
# []
# False
# Gragas wird zum Shop hinzugefügt.
# Zufälliger Champion: Shyvana
# []
# False
# Shyvana wird zum Shop hinzugefügt.
# Zufälliger Champion: Twisted Fate
# []
# False
# Twisted Fate wird zum Shop hinzugefügt.
# Zufälliger Champion: Kindred
# []
# False
# Kindred wird zum Shop hinzugefügt.
# Zufälliger Champion: Draven
# []
# False
# Draven wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# [[Champion(name=Seraphine, cost=1, traits=['Anima Squad', 'Techie'], star_level=1, png=downloaded_images/Seraphine.png), Champion(name=Sylas, cost=1, traits=['Anima Squad', 'Vanguard'], star_level=1, png=downloaded_images/Sylas.png), Champion(name=Kogmaw, cost=1, traits=['BoomBots', 'Rapidfire'], star_level=1, png=downloaded_images/Kogmaw.png), Champion(name=Poppy, cost=1, traits=['Cyberboss', 'Bastion'], star_level=1, png=downloaded_images/Poppy.png), Champion(name=Vi, cost=1, traits=['Cypher', 'Vanguard'], star_level=1, png=downloaded_images/Vi.png), Champion(name=Morgana, cost=1, traits=['Divinicorp', 'Dynamo'], star_level=1, png=downloaded_images/Morgana.png), Champion(name=Jax, cost=1, traits=['Exotech', 'Bastion'], star_level=1, png=downloaded_images/Jax.png), Champion(name=Alistar, cost=1, traits=['Golden Ox', 'Bruiser'], star_level=1, png=downloaded_images/Alistar.png), Champion(name=Kindred, cost=1, traits=['Nitro', 'Marksman', 'Rapidfire'], star_level=1, png=downloaded_images/Kindred.png), Champion(name=Nidalee, cost=1, traits=['Nitro', 'A.M.P.'], star_level=1, png=downloaded_images/Nidalee.png), Champion(name=Dr Mundo, cost=1, traits=['Street Demon', 'Bruiser', 'Slayer'], star_level=1, png=downloaded_images/Dr Mundo.png), Champion(name=Zyra, cost=1, traits=['Street Demon', 'Techie'], star_level=1, png=downloaded_images/Zyra.png), Champion(name=Shaco, cost=1, traits=['Syndicate', 'Slayer'], star_level=1, png=downloaded_images/Shaco.png)], [Champion(name=Illaoi, cost=2, traits=['Anima Squad', 'Bastion'], star_level=1, png=downloaded_images/Illaoi.png), Champion(name=Vayne, cost=2, traits=['Anima Squad', 'Slayer'], star_level=1, png=downloaded_images/Vayne.png), Champion(name=Skarner, cost=2, traits=['BoomBots', 'Vanguard'], star_level=1, png=downloaded_images/Skarner.png), Champion(name=Veigar, cost=2, traits=['Cyberboss', 'Techie'], star_level=1, png=downloaded_images/Veigar.png), Champion(name=Leblanc, cost=2, traits=['Cypher', 'Strategist'], star_level=1, png=downloaded_images/Leblanc.png), Champion(name=Rhaast, cost=2, traits=['Divinicorp', 'Vanguard'], star_level=1, png=downloaded_images/Rhaast.png), Champion(name=Jhin, cost=2, traits=['Exotech', 'Dynamo', 'Marksman'], star_level=1, png=downloaded_images/Jhin.png), Champion(name=Naafiri, cost=2, traits=['Exotech', 'A.M.P.'], star_level=1, png=downloaded_images/Naafiri.png), Champion(name=Graves, cost=2, traits=['Golden Ox', 'Executioner'], star_level=1, png=downloaded_images/Graves.png), Champion(name=Shyvana, cost=2, traits=['Nitro', 'Bastion', 'Techie'], star_level=1, png=downloaded_images/Shyvana.png), Champion(name=Ekko, cost=2, traits=['Street Demon', 'Strategist'], star_level=1, png=downloaded_images/Ekko.png), Champion(name=Darius, cost=2, traits=['Syndicate', 'Bruiser'], star_level=1, png=downloaded_images/Darius.png), Champion(name=Twisted Fate, cost=2, traits=['Syndicate', 'Rapidfire'], star_level=1, png=downloaded_images/Twisted Fate.png)], [Champion(name=Yuumi, cost=3, traits=['Anima Squad', 'A.M.P.', 'Strategist'], star_level=1, png=downloaded_images/Yuumi.png), Champion(name=Fiddlesticks, cost=3, traits=['BoomBots', 'Techie'], star_level=1, png=downloaded_images/Fiddlesticks.png), Champion(name=Draven, cost=3, traits=['Cypher', 'Rapidfire'], star_level=1, png=downloaded_images/Draven.png), Champion(name=Galio, cost=3, traits=['Cypher', 'Bastion'], star_level=1, png=downloaded_images/Galio.png), Champion(name=Gragas, cost=3, traits=['Divinicorp', 'Bruiser'], star_level=1, png=downloaded_images/Gragas.png), Champion(name=Senna, cost=3, traits=['Divinicorp', 'Slayer'], star_level=1, png=downloaded_images/Senna.png), Champion(name=Mordekaiser, cost=3, traits=['Exotech', 'Bruiser', 'Techie'], star_level=1, png=downloaded_images/Mordekaiser.png), Champion(name=Varus, cost=3, traits=['Exotech', 'Executioner'], star_level=1, png=downloaded_images/Varus.png), Champion(name=Jarvan IV, cost=3, traits=['Golden Ox', 'Slayer', 'Vanguard'], star_level=1, png=downl ...
# Platzieren des Labels für Seraphine bei Zeile 1, Spalte 0
# Platzieren des Labels für Sylas bei Zeile 1, Spalte 1
# Platzieren des Labels für Kogmaw bei Zeile 1, Spalte 2
# Platzieren des Labels für Poppy bei Zeile 1, Spalte 3
# Platzieren des Labels für Vi bei Zeile 2, Spalte 0
# Platzieren des Labels für Morgana bei Zeile 2, Spalte 1
# Platzieren des Labels für Jax bei Zeile 2, Spalte 2
# Platzieren des Labels für Alistar bei Zeile 2, Spalte 3
# Platzieren des Labels für Kindred bei Zeile 3, Spalte 0
# Platzieren des Labels für Nidalee bei Zeile 3, Spalte 1
# Platzieren des Labels für Dr Mundo bei Zeile 3, Spalte 2
# Platzieren des Labels für Zyra bei Zeile 3, Spalte 3
# Platzieren des Labels für Shaco bei Zeile 4, Spalte 0
# Platzieren des Labels für Illaoi bei Zeile 6, Spalte 0
# Platzieren des Labels für Vayne bei Zeile 6, Spalte 1
# Platzieren des Labels für Skarner bei Zeile 6, Spalte 2
# Platzieren des Labels für Veigar bei Zeile 6, Spalte 3
# Platzieren des Labels für Leblanc bei Zeile 7, Spalte 0
# Platzieren des Labels für Rhaast bei Zeile 7, Spalte 1
# Platzieren des Labels für Jhin bei Zeile 7, Spalte 2
# Platzieren des Labels für Naafiri bei Zeile 7, Spalte 3
# Platzieren des Labels für Graves bei Zeile 8, Spalte 0
# Platzieren des Labels für Shyvana bei Zeile 8, Spalte 1
# Platzieren des Labels für Ekko bei Zeile 8, Spalte 2
# Platzieren des Labels für Darius bei Zeile 8, Spalte 3
# Platzieren des Labels für Twisted Fate bei Zeile 9, Spalte 0
# Platzieren des Labels für Yuumi bei Zeile 11, Spalte 0
# Platzieren des Labels für Fiddlesticks bei Zeile 11, Spalte 1
# Platzieren des Labels für Draven bei Zeile 11, Spalte 2
# Platzieren des Labels für Galio bei Zeile 11, Spalte 3
# Platzieren des Labels für Gragas bei Zeile 12, Spalte 0
# Platzieren des Labels für Senna bei Zeile 12, Spalte 1
# Platzieren des Labels für Mordekaiser bei Zeile 12, Spalte 2
# Platzieren des Labels für Varus bei Zeile 12, Spalte 3
# Platzieren des Labels für Jarvan IV bei Zeile 13, Spalte 0
# Platzieren des Labels für Elise bei Zeile 13, Spalte 1
# Platzieren des Labels für Jinx bei Zeile 13, Spalte 2
# Platzieren des Labels für Rengar bei Zeile 13, Spalte 3
# Platzieren des Labels für Braum bei Zeile 14, Spalte 0
# Platzieren des Labels für Leona bei Zeile 16, Spalte 0
# Platzieren des Labels für Xayah bei Zeile 16, Spalte 1
# Platzieren des Labels für Chogath bei Zeile 16, Spalte 2
# Platzieren des Labels für Ziggs bei Zeile 16, Spalte 3
# Platzieren des Labels für Zed bei Zeile 17, Spalte 0
# Platzieren des Labels für Vex bei Zeile 17, Spalte 1
# Platzieren des Labels für Sejuani bei Zeile 17, Spalte 2
# Platzieren des Labels für Zeri bei Zeile 17, Spalte 3
# Platzieren des Labels für Annie bei Zeile 18, Spalte 0
# Platzieren des Labels für Aphelios bei Zeile 18, Spalte 1
# Platzieren des Labels für Brand bei Zeile 18, Spalte 2
# Platzieren des Labels für Neeko bei Zeile 18, Spalte 3
# Platzieren des Labels für Miss Fortune bei Zeile 19, Spalte 0
# Platzieren des Labels für Aurora bei Zeile 21, Spalte 0
# Platzieren des Labels für Urgot bei Zeile 21, Spalte 1
# Platzieren des Labels für Kobuko bei Zeile 21, Spalte 2
# Platzieren des Labels für Renekton bei Zeile 21, Spalte 3
# Platzieren des Labels für Garen bei Zeile 22, Spalte 0
# Platzieren des Labels für Viego bei Zeile 22, Spalte 1
# Platzieren des Labels für Samira bei Zeile 22, Spalte 2
# Platzieren des Labels für Zac bei Zeile 22, Spalte 3
# Nichts ist hier!
# Nichts ist hier!
# Nichts ist hier!
# Nichts ist hier!
# Nichts ist hier!
# Nichts ist hier!
# Nichts ist hier!
# Nichts ist hier!
# Nichts ist hier!
# Nichts ist hier!
# Hier [None, None, None, None, None, None, None, None, None, None]
# Champion Neeko wurde zur Liste an Position 0 hinzugefügt.
# [Champion(name=Neeko, cost=4, traits=['Street Demon', 'Strategist'], star_level=1, png=downloaded_images/Neeko.png), None, None, None, None, None, None, None, None, None]
# Nichts ist hier!
# Nichts ist hier!
# Nichts ist hier!
# Nichts ist hier!
# Nichts ist hier!
# Nichts ist hier!
# Nichts ist hier!
# Nichts ist hier!
# Nichts ist hier!
# Hier [Champion(name=Neeko, cost=4, traits=['Street Demon', 'Strategist'], star_level=1, png=downloaded_images/Neeko.png), None, None, None, None, None, None, None, None, None]
# Champion Brand wurde zur Liste an Position 1 hinzugefügt.
# [Champion(name=Neeko, cost=4, traits=['Street Demon', 'Strategist'], star_level=1, png=downloaded_images/Neeko.png), Champion(name=Brand, cost=4, traits=['Street Demon', 'Techie'], star_level=1, png=downloaded_images/Brand.png), None, None, None, None, None, None, None, None]
# Nichts ist hier!
# Nichts ist hier!
# Nichts ist hier!
# Nichts ist hier!
# Nichts ist hier!
# Nichts ist hier!
# Nichts ist hier!
# Nichts ist hier!
# Hier [Champion(name=Neeko, cost=4, traits=['Street Demon', 'Strategist'], star_level=1, png=downloaded_images/Neeko.png), Champion(name=Brand, cost=4, traits=['Street Demon', 'Techie'], star_level=1, png=downloaded_images/Brand.png), None, None, None, None, None, None, None, None]
# Champion Vex wurde zur Liste an Position 2 hinzugefügt.
# [Champion(name=Neeko, cost=4, traits=['Street Demon', 'Strategist'], star_level=1, png=downloaded_images/Neeko.png), Champion(name=Brand, cost=4, traits=['Street Demon', 'Techie'], star_level=1, png=downloaded_images/Brand.png), Champion(name=Vex, cost=4, traits=['Divinicorp', 'Executioner'], star_level=1, png=downloaded_images/Vex.png), None, None, None, None, None, None, None]
# Nichts ist hier!
# Nichts ist hier!
# Nichts ist hier!
# Nichts ist hier!
# Nichts ist hier!
# Nichts ist hier!
# Nichts ist hier!
# Hier [Champion(name=Neeko, cost=4, traits=['Street Demon', 'Strategist'], star_level=1, png=downloaded_images/Neeko.png), Champion(name=Brand, cost=4, traits=['Street Demon', 'Techie'], star_level=1, png=downloaded_images/Brand.png), Champion(name=Vex, cost=4, traits=['Divinicorp', 'Executioner'], star_level=1, png=downloaded_images/Vex.png), None, None, None, None, None, None, None]
# Zufälliger Champion: Jax
# []
# False
# Jax wird zum Shop hinzugefügt.
# Zufälliger Champion: Jarvan IV
# []
# False
# Jarvan IV wird zum Shop hinzugefügt.
# Zufälliger Champion: Sejuani
# []
# False
# Sejuani wird zum Shop hinzugefügt.
# Zufälliger Champion: Dr Mundo
# []
# False
# Dr Mundo wird zum Shop hinzugefügt.
# Zufälliger Champion: Gragas
# []
# False
# Gragas wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Jarvan IV
# []
# False
# Jarvan IV wird zum Shop hinzugefügt.
# Zufälliger Champion: Illaoi
# []
# False
# Illaoi wird zum Shop hinzugefügt.
# Zufälliger Champion: Seraphine
# []
# False
# Seraphine wird zum Shop hinzugefügt.
# Zufälliger Champion: Jarvan IV
# []
# False
# Jarvan IV wird zum Shop hinzugefügt.
# Zufälliger Champion: Rengar
# []
# False
# Rengar wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Zeri
# []
# False
# Zeri wird zum Shop hinzugefügt.
# Zufälliger Champion: Rhaast
# []
# False
# Rhaast wird zum Shop hinzugefügt.
# Zufälliger Champion: Vi
# []
# False
# Vi wird zum Shop hinzugefügt.
# Zufälliger Champion: Leona
# []
# False
# Leona wird zum Shop hinzugefügt.
# Zufälliger Champion: Braum
# []
# False
# Braum wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Vex
# []
# False
# Vex wird zum Shop hinzugefügt.
# Zufälliger Champion: Zed
# []
# False
# Zed wird zum Shop hinzugefügt.
# Zufälliger Champion: Sejuani
# []
# False
# Sejuani wird zum Shop hinzugefügt.
# Zufälliger Champion: Leblanc
# []
# False
# Leblanc wird zum Shop hinzugefügt.
# Zufälliger Champion: Sylas
# []
# False
# Sylas wird zum Shop hinzugefügt.
# Gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Braum
# []
# False
# Braum wird zum Shop hinzugefügt.
# Zufälliger Champion: Graves
# []
# False
# Graves wird zum Shop hinzugefügt.
# Zufälliger Champion: Fiddlesticks
# []
# False
# Fiddlesticks wird zum Shop hinzugefügt.
# Zufälliger Champion: Zyra
# []
# False
# Zyra wird zum Shop hinzugefügt.
# Zufälliger Champion: Brand
# []
# False
# Brand wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Gefunden
# Der Champ Brand wird gekauft!
# Brand wurde gekauft!
# 32
# Warnung: Keine Champions in den Slots!
# Keine Units auf dem Feld!
# Zufälliger Champion: Yuumi
# []
# False
# Yuumi wird zum Shop hinzugefügt.
# Zufälliger Champion: Naafiri
# []
# False
# Naafiri wird zum Shop hinzugefügt.
# Zufälliger Champion: Neeko
# []
# False
# Neeko wird zum Shop hinzugefügt.
# Zufälliger Champion: Twisted Fate
# []
# False
# Twisted Fate wird zum Shop hinzugefügt.
# Zufälliger Champion: Veigar
# []
# False
# Veigar wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Senna
# []
# False
# Senna wird zum Shop hinzugefügt.
# Zufälliger Champion: Leblanc
# []
# False
# Leblanc wird zum Shop hinzugefügt.
# Zufälliger Champion: Miss Fortune
# []
# False
# Miss Fortune wird zum Shop hinzugefügt.
# Zufälliger Champion: Sylas
# []
# False
# Sylas wird zum Shop hinzugefügt.
# Zufälliger Champion: Zed
# []
# False
# Zed wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Draven
# []
# False
# Draven wird zum Shop hinzugefügt.
# Zufälliger Champion: Kogmaw
# []
# False
# Kogmaw wird zum Shop hinzugefügt.
# Zufälliger Champion: Galio
# []
# False
# Galio wird zum Shop hinzugefügt.
# Zufälliger Champion: Alistar
# []
# False
# Alistar wird zum Shop hinzugefügt.
# Zufälliger Champion: Jhin
# []
# False
# Jhin wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Sejuani
# []
# False
# Sejuani wird zum Shop hinzugefügt.
# Zufälliger Champion: Elise
# []
# False
# Elise wird zum Shop hinzugefügt.
# Zufälliger Champion: Veigar
# []
# False
# Veigar wird zum Shop hinzugefügt.
# Zufälliger Champion: Aphelios
# []
# False
# Aphelios wird zum Shop hinzugefügt.
# Zufälliger Champion: Jhin
# []
# False
# Jhin wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Draven
# []
# False
# Draven wird zum Shop hinzugefügt.
# Zufälliger Champion: Varus
# []
# False
# Varus wird zum Shop hinzugefügt.
# Zufälliger Champion: Sylas
# []
# False
# Sylas wird zum Shop hinzugefügt.
# Zufälliger Champion: Varus
# []
# False
# Varus wird zum Shop hinzugefügt.
# Zufälliger Champion: Twisted Fate
# []
# False
# Twisted Fate wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Neeko
# []
# False
# Neeko wird zum Shop hinzugefügt.
# Zufälliger Champion: Alistar
# []
# False
# Alistar wird zum Shop hinzugefügt.
# Zufälliger Champion: Gragas
# []
# False
# Gragas wird zum Shop hinzugefügt.
# Zufälliger Champion: Leona
# []
# False
# Leona wird zum Shop hinzugefügt.
# Zufälliger Champion: Ekko
# []
# False
# Ekko wird zum Shop hinzugefügt.
# Gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Der Champ Neeko wird gekauft!
# Neeko wurde gekauft!
# 32
# Warnung: Keine Champions in den Slots!
# Keine Units auf dem Feld!
# Zufälliger Champion: Skarner
# []
# False
# Skarner wird zum Shop hinzugefügt.
# Zufälliger Champion: Braum
# []
# False
# Braum wird zum Shop hinzugefügt.
# Zufälliger Champion: Naafiri
# []
# False
# Naafiri wird zum Shop hinzugefügt.
# Zufälliger Champion: Senna
# []
# False
# Senna wird zum Shop hinzugefügt.
# Zufälliger Champion: Veigar
# []
# False
# Veigar wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Graves
# []
# False
# Graves wird zum Shop hinzugefügt.
# Zufälliger Champion: Varus
# []
# False
# Varus wird zum Shop hinzugefügt.
# Zufälliger Champion: Rengar
# []
# False
# Rengar wird zum Shop hinzugefügt.
# Zufälliger Champion: Rengar
# []
# False
# Rengar wird zum Shop hinzugefügt.
# Zufälliger Champion: Rengar
# []
# False
# Rengar wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Shyvana
# []
# False
# Shyvana wird zum Shop hinzugefügt.
# Zufälliger Champion: Neeko
# []
# False
# Neeko wird zum Shop hinzugefügt.
# Zufälliger Champion: Leblanc
# []
# False
# Leblanc wird zum Shop hinzugefügt.
# Zufälliger Champion: Ziggs
# []
# False
# Ziggs wird zum Shop hinzugefügt.
# Zufälliger Champion: Kogmaw
# []
# False
# Kogmaw wird zum Shop hinzugefügt.
# Nicht gefunden
# Gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Der Champ Neeko wird gekauft!
# Neeko wurde gekauft!
# 32
# Warnung: Keine Champions in den Slots!
# Keine Units auf dem Feld!
# Zufälliger Champion: Illaoi
# []
# False
# Illaoi wird zum Shop hinzugefügt.
# Zufälliger Champion: Naafiri
# []
# False
# Naafiri wird zum Shop hinzugefügt.
# Zufälliger Champion: Rengar
# []
# False
# Rengar wird zum Shop hinzugefügt.
# Zufälliger Champion: Miss Fortune
# []
# False
# Miss Fortune wird zum Shop hinzugefügt.
# Zufälliger Champion: Illaoi
# []
# False
# Illaoi wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Leona
# []
# False
# Leona wird zum Shop hinzugefügt.
# Zufälliger Champion: Seraphine
# []
# False
# Seraphine wird zum Shop hinzugefügt.
# Zufälliger Champion: Senna
# []
# False
# Senna wird zum Shop hinzugefügt.
# Zufälliger Champion: Jarvan IV
# []
# False
# Jarvan IV wird zum Shop hinzugefügt.
# Zufälliger Champion: Annie
# []
# False
# Annie wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Shyvana
# []
# False
# Shyvana wird zum Shop hinzugefügt.
# Zufälliger Champion: Senna
# []
# False
# Senna wird zum Shop hinzugefügt.
# Zufälliger Champion: Zyra
# []
# False
# Zyra wird zum Shop hinzugefügt.
# Zufälliger Champion: Graves
# []
# False
# Graves wird zum Shop hinzugefügt.
# Zufälliger Champion: Graves
# []
# False
# Graves wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Xayah
# []
# False
# Xayah wird zum Shop hinzugefügt.
# Zufälliger Champion: Naafiri
# []
# False
# Naafiri wird zum Shop hinzugefügt.
# Zufälliger Champion: Senna
# []
# False
# Senna wird zum Shop hinzugefügt.
# Zufälliger Champion: Galio
# []
# False
# Galio wird zum Shop hinzugefügt.
# Zufälliger Champion: Elise
# []
# False
# Elise wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Jax
# []
# False
# Jax wird zum Shop hinzugefügt.
# Zufälliger Champion: Morgana
# []
# False
# Morgana wird zum Shop hinzugefügt.
# Zufälliger Champion: Yuumi
# []
# False
# Yuumi wird zum Shop hinzugefügt.
# Zufälliger Champion: Varus
# []
# False
# Varus wird zum Shop hinzugefügt.
# Zufälliger Champion: Draven
# []
# False
# Draven wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Vayne
# []
# False
# Vayne wird zum Shop hinzugefügt.
# Zufälliger Champion: Rhaast
# []
# False
# Rhaast wird zum Shop hinzugefügt.
# Zufälliger Champion: Vex
# []
# False
# Vex wird zum Shop hinzugefügt.
# Zufälliger Champion: Leblanc
# []
# False
# Leblanc wird zum Shop hinzugefügt.
# Zufälliger Champion: Varus
# []
# False
# Varus wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Gefunden
# Nicht gefunden
# Nicht gefunden
# Der Champ Vex wird gekauft!
# Vex wurde gekauft!
# 32
# Warnung: Keine Champions in den Slots!
# Keine Units auf dem Feld!
# Zufälliger Champion: Galio
# []
# False
# Galio wird zum Shop hinzugefügt.
# Zufälliger Champion: Miss Fortune
# []
# False
# Miss Fortune wird zum Shop hinzugefügt.
# Zufälliger Champion: Illaoi
# []
# False
# Illaoi wird zum Shop hinzugefügt.
# Zufälliger Champion: Vayne
# []
# False
# Vayne wird zum Shop hinzugefügt.
# Zufälliger Champion: Sejuani
# []
# False
# Sejuani wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Elise
# []
# False
# Elise wird zum Shop hinzugefügt.
# Zufälliger Champion: Rengar
# []
# False
# Rengar wird zum Shop hinzugefügt.
# Zufälliger Champion: Yuumi
# []
# False
# Yuumi wird zum Shop hinzugefügt.
# Zufälliger Champion: Shyvana
# []
# False
# Shyvana wird zum Shop hinzugefügt.
# Zufälliger Champion: Twisted Fate
# []
# False
# Twisted Fate wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Annie
# []
# False
# Annie wird zum Shop hinzugefügt.
# Zufälliger Champion: Chogath
# []
# False
# Chogath wird zum Shop hinzugefügt.
# Zufälliger Champion: Annie
# []
# False
# Annie wird zum Shop hinzugefügt.
# Zufälliger Champion: Morgana
# []
# False
# Morgana wird zum Shop hinzugefügt.
# Zufälliger Champion: Dr Mundo
# []
# False
# Dr Mundo wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Braum
# []
# False
# Braum wird zum Shop hinzugefügt.
# Zufälliger Champion: Darius
# []
# False
# Darius wird zum Shop hinzugefügt.
# Zufälliger Champion: Nidalee
# []
# False
# Nidalee wird zum Shop hinzugefügt.
# Zufälliger Champion: Sejuani
# []
# False
# Sejuani wird zum Shop hinzugefügt.
# Zufälliger Champion: Morgana
# []
# False
# Morgana wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Ekko
# []
# False
# Ekko wird zum Shop hinzugefügt.
# Zufälliger Champion: Alistar
# []
# False
# Alistar wird zum Shop hinzugefügt.
# Zufälliger Champion: Jax
# []
# False
# Jax wird zum Shop hinzugefügt.
# Zufälliger Champion: Veigar
# []
# False
# Veigar wird zum Shop hinzugefügt.
# Zufälliger Champion: Brand
# []
# False
# Brand wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Gefunden
# Zufälliger Champion: Shyvana
# []
# False
# Shyvana wird zum Shop hinzugefügt.
# Zufälliger Champion: Aphelios
# []
# False
# Aphelios wird zum Shop hinzugefügt.
# Zufälliger Champion: Jinx
# []
# False
# Jinx wird zum Shop hinzugefügt.
# Zufälliger Champion: Chogath
# []
# False
# Chogath wird zum Shop hinzugefügt.
# Zufälliger Champion: Naafiri
# []
# False
# Naafiri wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Mordekaiser
# []
# False
# Mordekaiser wird zum Shop hinzugefügt.
# Zufälliger Champion: Sejuani
# []
# False
# Sejuani wird zum Shop hinzugefügt.
# Zufälliger Champion: Zyra
# []
# False
# Zyra wird zum Shop hinzugefügt.
# Zufälliger Champion: Illaoi
# []
# False
# Illaoi wird zum Shop hinzugefügt.
# Zufälliger Champion: Zeri
# []
# False
# Zeri wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Vayne
# []
# False
# Vayne wird zum Shop hinzugefügt.
# Zufälliger Champion: Vi
# []
# False
# Vi wird zum Shop hinzugefügt.
# Zufälliger Champion: Yuumi
# []
# False
# Yuumi wird zum Shop hinzugefügt.
# Zufälliger Champion: Yuumi
# []
# False
# Yuumi wird zum Shop hinzugefügt.
# Zufälliger Champion: Vi
# []
# False
# Vi wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Leblanc
# []
# False
# Leblanc wird zum Shop hinzugefügt.
# Zufälliger Champion: Jarvan IV
# []
# False
# Jarvan IV wird zum Shop hinzugefügt.
# Zufälliger Champion: Zeri
# []
# False
# Zeri wird zum Shop hinzugefügt.
# Zufälliger Champion: Seraphine
# []
# False
# Seraphine wird zum Shop hinzugefügt.
# Zufälliger Champion: Zeri
# []
# False
# Zeri wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Shaco
# []
# False
# Shaco wird zum Shop hinzugefügt.
# Zufälliger Champion: Mordekaiser
# []
# False
# Mordekaiser wird zum Shop hinzugefügt.
# Zufälliger Champion: Jarvan IV
# []
# False
# Jarvan IV wird zum Shop hinzugefügt.
# Zufälliger Champion: Elise
# []
# False
# Elise wird zum Shop hinzugefügt.
# Zufälliger Champion: Galio
# []
# False
# Galio wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Rengar
# []
# False
# Rengar wird zum Shop hinzugefügt.
# Zufälliger Champion: Gragas
# []
# False
# Gragas wird zum Shop hinzugefügt.
# Zufälliger Champion: Ziggs
# []
# False
# Ziggs wird zum Shop hinzugefügt.
# Zufälliger Champion: Fiddlesticks
# []
# False
# Fiddlesticks wird zum Shop hinzugefügt.
# Zufälliger Champion: Jax
# []
# False
# Jax wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Fiddlesticks
# []
# False
# Fiddlesticks wird zum Shop hinzugefügt.
# Zufälliger Champion: Alistar
# []
# False
# Alistar wird zum Shop hinzugefügt.
# Zufälliger Champion: Viego
# []
# False
# Viego wird zum Shop hinzugefügt.
# Zufälliger Champion: Senna
# []
# False
# Senna wird zum Shop hinzugefügt.
# Zufälliger Champion: Vi
# []
# False
# Vi wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Der Champ Viego wird gekauft!
# Viego wurde gekauft!
# 32
# Warnung: Keine Champions in den Slots!
# Keine Units auf dem Feld!
# Zufälliger Champion: Mordekaiser
# []
# False
# Mordekaiser wird zum Shop hinzugefügt.
# Zufälliger Champion: Shaco
# []
# False
# Shaco wird zum Shop hinzugefügt.
# Zufälliger Champion: Annie
# []
# False
# Annie wird zum Shop hinzugefügt.
# Zufälliger Champion: Zyra
# []
# False
# Zyra wird zum Shop hinzugefügt.
# Zufälliger Champion: Twisted Fate
# []
# False
# Twisted Fate wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# 464 und 817
# Unit auf Feld gesetzt!
# 0 und 7
# Champion(name=Brand, cost=4, traits=['Street Demon', 'Techie'], star_level=1, png=downloaded_images/Brand.png)
# Brand
# 32
# [Champion(name=Brand, cost=4, traits=['Street Demon', 'Techie'], star_level=1, png=downloaded_images/Brand.png), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# ('Brand', ('Street Demon', 'Techie'))
# {'Street Demon': 1, 'Techie': 1}
# {'Street Demon': 1, 'Techie': 1}
# 527 und 813
# Unit auf Feld gesetzt!
# 1 und 7
# Champion(name=Neeko, cost=4, traits=['Street Demon', 'Strategist'], star_level=1, png=downloaded_images/Neeko.png)
# Neeko
# 32
# [Champion(name=Brand, cost=4, traits=['Street Demon', 'Techie'], star_level=1, png=downloaded_images/Brand.png), Champion(name=Neeko, cost=4, traits=['Street Demon', 'Strategist'], star_level=1, png=downloaded_images/Neeko.png), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# ('Brand', ('Street Demon', 'Techie'))
# ('Neeko', ('Strategist', 'Street Demon'))
# {'Street Demon': 2, 'Techie': 1, 'Strategist': 1}
# {'Street Demon': 2, 'Techie': 1, 'Strategist': 1}
# 785 und 813
# Unit auf Feld gesetzt!
# 2 und 7
# Champion(name=Vex, cost=4, traits=['Divinicorp', 'Executioner'], star_level=1, png=downloaded_images/Vex.png)
# Vex
# 32
# [Champion(name=Brand, cost=4, traits=['Street Demon', 'Techie'], star_level=1, png=downloaded_images/Brand.png), Champion(name=Neeko, cost=4, traits=['Street Demon', 'Strategist'], star_level=1, png=downloaded_images/Neeko.png), Champion(name=Vex, cost=4, traits=['Divinicorp', 'Executioner'], star_level=1, png=downloaded_images/Vex.png), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# ('Brand', ('Street Demon', 'Techie'))
# ('Neeko', ('Strategist', 'Street Demon'))
# ('Vex', ('Divinicorp', 'Executioner'))
# {'Street Demon': 2, 'Techie': 1, 'Strategist': 1, 'Divinicorp': 1, 'Executioner': 1}
# {'Street Demon': 2, 'Techie': 1, 'Strategist': 1, 'Divinicorp': 1, 'Executioner': 1}
# 850 und 809
# Unit auf Feld gesetzt!
# 3 und 7
# Champion(name=Viego, cost=5, traits=['Golden Ox', 'Soul Killer', 'Techie'], star_level=1, png=downloaded_images/Viego.png)
# Viego
# 32
# [Champion(name=Brand, cost=4, traits=['Street Demon', 'Techie'], star_level=1, png=downloaded_images/Brand.png), Champion(name=Neeko, cost=4, traits=['Street Demon', 'Strategist'], star_level=1, png=downloaded_images/Neeko.png), Champion(name=Vex, cost=4, traits=['Divinicorp', 'Executioner'], star_level=1, png=downloaded_images/Vex.png), Champion(name=Viego, cost=5, traits=['Golden Ox', 'Soul Killer', 'Techie'], star_level=1, png=downloaded_images/Viego.png), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# ('Brand', ('Street Demon', 'Techie'))
# ('Neeko', ('Strategist', 'Street Demon'))
# ('Vex', ('Divinicorp', 'Executioner'))
# ('Viego', ('Golden Ox', 'Soul Killer', 'Techie'))
# {'Street Demon': 2, 'Techie': 2, 'Strategist': 1, 'Divinicorp': 1, 'Executioner': 1, 'Golden Ox': 1, 'Soul Killer': 1}
# {'Street Demon': 2, 'Techie': 2, 'Strategist': 1, 'Divinicorp': 1, 'Executioner': 1, 'Golden Ox': 1, 'Soul Killer': 1}
# Zufälliger Champion: Shaco
# []
# False
# Shaco wird zum Shop hinzugefügt.
# Zufälliger Champion: Graves
# []
# False
# Graves wird zum Shop hinzugefügt.
# Zufälliger Champion: Draven
# []
# False
# Draven wird zum Shop hinzugefügt.
# Zufälliger Champion: Darius
# []
# False
# Darius wird zum Shop hinzugefügt.
# Zufälliger Champion: Zed
# []
# False
# Zed wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# 658 und 796
# Unit auf Feld gesetzt!
# 4 und 7
# Champion(name=Neeko, cost=4, traits=['Street Demon', 'Strategist'], star_level=1, png=downloaded_images/Neeko.png)
# Neeko
# 32
# [Champion(name=Brand, cost=4, traits=['Street Demon', 'Techie'], star_level=1, png=downloaded_images/Brand.png), Champion(name=Neeko, cost=4, traits=['Street Demon', 'Strategist'], star_level=1, png=downloaded_images/Neeko.png), Champion(name=Vex, cost=4, traits=['Divinicorp', 'Executioner'], star_level=1, png=downloaded_images/Vex.png), Champion(name=Viego, cost=5, traits=['Golden Ox', 'Soul Killer', 'Techie'], star_level=1, png=downloaded_images/Viego.png), Champion(name=Neeko, cost=4, traits=['Street Demon', 'Strategist'], star_level=1, png=downloaded_images/Neeko.png), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# ('Brand', ('Street Demon', 'Techie'))
# ('Neeko', ('Strategist', 'Street Demon'))
# ('Vex', ('Divinicorp', 'Executioner'))
# ('Viego', ('Golden Ox', 'Soul Killer', 'Techie'))
# ('Neeko', ('Strategist', 'Street Demon'))
# {'Street Demon': 2, 'Techie': 2, 'Strategist': 1, 'Divinicorp': 1, 'Executioner': 1, 'Golden Ox': 1, 'Soul Killer': 1}
# {'Street Demon': 2, 'Techie': 2, 'Strategist': 1, 'Divinicorp': 1, 'Executioner': 1, 'Golden Ox': 1, 'Soul Killer': 1}
# Zufälliger Champion: Gragas
# []
# False
# Gragas wird zum Shop hinzugefügt.
# Zufälliger Champion: Sejuani
# []
# False
# Sejuani wird zum Shop hinzugefügt.
# Zufälliger Champion: Aphelios
# []
# False
# Aphelios wird zum Shop hinzugefügt.
# Zufälliger Champion: Dr Mundo
# []
# False
# Dr Mundo wird zum Shop hinzugefügt.
# Zufälliger Champion: Aphelios
# []
# False
# Aphelios wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Shyvana
# []
# False
# Shyvana wird zum Shop hinzugefügt.
# Zufälliger Champion: Alistar
# []
# False
# Alistar wird zum Shop hinzugefügt.
# Zufälliger Champion: Jax
# []
# False
# Jax wird zum Shop hinzugefügt.
# Zufälliger Champion: Jax
# []
# False
# Jax wird zum Shop hinzugefügt.
# Zufälliger Champion: Kogmaw
# []
# False
# Kogmaw wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Senna
# []
# False
# Senna wird zum Shop hinzugefügt.
# Zufälliger Champion: Aurora
# []
# False
# Aurora wird zum Shop hinzugefügt.
# Zufälliger Champion: Fiddlesticks
# []
# False
# Fiddlesticks wird zum Shop hinzugefügt.
# Zufälliger Champion: Vi
# []
# False
# Vi wird zum Shop hinzugefügt.
# Zufälliger Champion: Senna
# []
# False
# Senna wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Der Champ Aurora wird gekauft!
# Aurora wurde gekauft!
# 32
# [Champion(name=Brand, cost=4, traits=['Street Demon', 'Techie'], star_level=1, png=downloaded_images/Brand.png), Champion(name=Neeko, cost=4, traits=['Street Demon', 'Strategist'], star_level=1, png=downloaded_images/Neeko.png), Champion(name=Vex, cost=4, traits=['Divinicorp', 'Executioner'], star_level=1, png=downloaded_images/Vex.png), Champion(name=Viego, cost=5, traits=['Golden Ox', 'Soul Killer', 'Techie'], star_level=1, png=downloaded_images/Viego.png), Champion(name=Neeko, cost=4, traits=['Street Demon', 'Strategist'], star_level=1, png=downloaded_images/Neeko.png), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# ('Brand', ('Street Demon', 'Techie'))
# ('Neeko', ('Strategist', 'Street Demon'))
# ('Vex', ('Divinicorp', 'Executioner'))
# ('Viego', ('Golden Ox', 'Soul Killer', 'Techie'))
# ('Neeko', ('Strategist', 'Street Demon'))
# {'Street Demon': 2, 'Techie': 2, 'Strategist': 1, 'Divinicorp': 1, 'Executioner': 1, 'Golden Ox': 1, 'Soul Killer': 1}
# {'Street Demon': 2, 'Techie': 2, 'Strategist': 1, 'Divinicorp': 1, 'Executioner': 1, 'Golden Ox': 1, 'Soul Killer': 1}
# Zufälliger Champion: Xayah
# []
# False
# Xayah wird zum Shop hinzugefügt.
# Zufälliger Champion: Zed
# []
# False
# Zed wird zum Shop hinzugefügt.
# Zufälliger Champion: Morgana
# []
# False
# Morgana wird zum Shop hinzugefügt.
# Zufälliger Champion: Graves
# []
# False
# Graves wird zum Shop hinzugefügt.
# Zufälliger Champion: Varus
# []
# False
# Varus wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Darius
# []
# False
# Darius wird zum Shop hinzugefügt.
# Zufälliger Champion: Garen
# []
# False
# Garen wird zum Shop hinzugefügt.
# Zufälliger Champion: Varus
# []
# False
# Varus wird zum Shop hinzugefügt.
# Zufälliger Champion: Jarvan IV
# []
# False
# Jarvan IV wird zum Shop hinzugefügt.
# Zufälliger Champion: Xayah
# []
# False
# Xayah wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Der Champ Garen wird gekauft!
# Garen wurde gekauft!
# 32
# [Champion(name=Brand, cost=4, traits=['Street Demon', 'Techie'], star_level=1, png=downloaded_images/Brand.png), Champion(name=Neeko, cost=4, traits=['Street Demon', 'Strategist'], star_level=1, png=downloaded_images/Neeko.png), Champion(name=Vex, cost=4, traits=['Divinicorp', 'Executioner'], star_level=1, png=downloaded_images/Vex.png), Champion(name=Viego, cost=5, traits=['Golden Ox', 'Soul Killer', 'Techie'], star_level=1, png=downloaded_images/Viego.png), Champion(name=Neeko, cost=4, traits=['Street Demon', 'Strategist'], star_level=1, png=downloaded_images/Neeko.png), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# ('Brand', ('Street Demon', 'Techie'))
# ('Neeko', ('Strategist', 'Street Demon'))
# ('Vex', ('Divinicorp', 'Executioner'))
# ('Viego', ('Golden Ox', 'Soul Killer', 'Techie'))
# ('Neeko', ('Strategist', 'Street Demon'))
# {'Street Demon': 2, 'Techie': 2, 'Strategist': 1, 'Divinicorp': 1, 'Executioner': 1, 'Golden Ox': 1, 'Soul Killer': 1}
# {'Street Demon': 2, 'Techie': 2, 'Strategist': 1, 'Divinicorp': 1, 'Executioner': 1, 'Golden Ox': 1, 'Soul Killer': 1}
# Zufälliger Champion: Senna
# []
# False
# Senna wird zum Shop hinzugefügt.
# Zufälliger Champion: Gragas
# []
# False
# Gragas wird zum Shop hinzugefügt.
# Zufälliger Champion: Rengar
# []
# False
# Rengar wird zum Shop hinzugefügt.
# Zufälliger Champion: Kindred
# []
# False
# Kindred wird zum Shop hinzugefügt.
# Zufälliger Champion: Galio
# []
# False
# Galio wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Garen
# []
# False
# Garen wird zum Shop hinzugefügt.
# Zufälliger Champion: Jinx
# []
# False
# Jinx wird zum Shop hinzugefügt.
# Zufälliger Champion: Xayah
# []
# False
# Xayah wird zum Shop hinzugefügt.
# Zufälliger Champion: Miss Fortune
# []
# False
# Miss Fortune wird zum Shop hinzugefügt.
# Zufälliger Champion: Leona
# []
# False
# Leona wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Der Champ Garen wird gekauft!
# Garen wurde gekauft!
# 32
# [Champion(name=Brand, cost=4, traits=['Street Demon', 'Techie'], star_level=1, png=downloaded_images/Brand.png), Champion(name=Neeko, cost=4, traits=['Street Demon', 'Strategist'], star_level=1, png=downloaded_images/Neeko.png), Champion(name=Vex, cost=4, traits=['Divinicorp', 'Executioner'], star_level=1, png=downloaded_images/Vex.png), Champion(name=Viego, cost=5, traits=['Golden Ox', 'Soul Killer', 'Techie'], star_level=1, png=downloaded_images/Viego.png), Champion(name=Neeko, cost=4, traits=['Street Demon', 'Strategist'], star_level=1, png=downloaded_images/Neeko.png), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# ('Brand', ('Street Demon', 'Techie'))
# ('Neeko', ('Strategist', 'Street Demon'))
# ('Vex', ('Divinicorp', 'Executioner'))
# ('Viego', ('Golden Ox', 'Soul Killer', 'Techie'))
# ('Neeko', ('Strategist', 'Street Demon'))
# {'Street Demon': 2, 'Techie': 2, 'Strategist': 1, 'Divinicorp': 1, 'Executioner': 1, 'Golden Ox': 1, 'Soul Killer': 1}
# {'Street Demon': 2, 'Techie': 2, 'Strategist': 1, 'Divinicorp': 1, 'Executioner': 1, 'Golden Ox': 1, 'Soul Killer': 1}
# Zufälliger Champion: Sylas
# []
# False
# Sylas wird zum Shop hinzugefügt.
# Zufälliger Champion: Nidalee
# []
# False
# Nidalee wird zum Shop hinzugefügt.
# Zufälliger Champion: Zeri
# []
# False
# Zeri wird zum Shop hinzugefügt.
# Zufälliger Champion: Yuumi
# []
# False
# Yuumi wird zum Shop hinzugefügt.
# Zufälliger Champion: Jarvan IV
# []
# False
# Jarvan IV wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Jarvan IV
# []
# False
# Jarvan IV wird zum Shop hinzugefügt.
# Zufälliger Champion: Jax
# []
# False
# Jax wird zum Shop hinzugefügt.
# Zufälliger Champion: Xayah
# []
# False
# Xayah wird zum Shop hinzugefügt.
# Zufälliger Champion: Skarner
# []
# False
# Skarner wird zum Shop hinzugefügt.
# Zufälliger Champion: Miss Fortune
# []
# False
# Miss Fortune wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Alistar
# []
# False
# Alistar wird zum Shop hinzugefügt.
# Zufälliger Champion: Kogmaw
# []
# False
# Kogmaw wird zum Shop hinzugefügt.
# Zufälliger Champion: Morgana
# []
# False
# Morgana wird zum Shop hinzugefügt.
# Zufälliger Champion: Gragas
# []
# False
# Gragas wird zum Shop hinzugefügt.
# Zufälliger Champion: Leona
# []
# False
# Leona wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Miss Fortune
# []
# False
# Miss Fortune wird zum Shop hinzugefügt.
# Zufälliger Champion: Darius
# []
# False
# Darius wird zum Shop hinzugefügt.
# Zufälliger Champion: Ziggs
# []
# False
# Ziggs wird zum Shop hinzugefügt.
# Zufälliger Champion: Senna
# []
# False
# Senna wird zum Shop hinzugefügt.
# Zufälliger Champion: Zed
# []
# False
# Zed wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Nicht gefunden
# Zufälliger Champion: Varus
# []
# False
# Varus wird zum Shop hinzugefügt.
# Zufälliger Champion: Chogath
# []
# False
# Chogath wird zum Shop hinzugefügt.
# Zufälliger Champion: Neeko
# []
# False
# Neeko wird zum Shop hinzugefügt.
# Es gibt mindestens zwei Objekte mit denselben Attributen.
# Du hast ein Duplikat von Neeko!
# Highlighte Neeko!
# Zufälliger Champion: Neeko
# []
# False
# Neeko wird zum Shop hinzugefügt.
# Es gibt mindestens zwei Objekte mit denselben Attributen.
# Du hast ein Duplikat von Neeko!
# Highlighte Neeko!
# Zufälliger Champion: Braum
# []
# False
# Braum wird zum Shop hinzugefügt.
# Nicht gefunden
# Nicht gefunden
# Gefunden
# Gefunden
# Nicht gefunden
# Der Champ Neeko wird gekauft!
# Es gibt mindestens zwei Objekte mit denselben Attributen.
# Neeko wird upgegraded!
# Drei dieser Champs werden nun zu einer kombiniert!
# Neeko wurde gekauft!
# 32
# [Champion(name=Brand, cost=4, traits=['Street Demon', 'Techie'], star_level=1, png=downloaded_images/Brand.png), None, Champion(name=Vex, cost=4, traits=['Divinicorp', 'Executioner'], star_level=1, png=downloaded_images/Vex.png), Champion(name=Viego, cost=5, traits=['Golden Ox', 'Soul Killer', 'Techie'], star_level=1, png=downloaded_images/Viego.png), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# ('Brand', ('Street Demon', 'Techie'))
# ('Vex', ('Divinicorp', 'Executioner'))
# ('Viego', ('Golden Ox', 'Soul Killer', 'Techie'))
# {'Techie': 2, 'Street Demon': 1, 'Divinicorp': 1, 'Executioner': 1, 'Golden Ox': 1, 'Soul Killer': 1}
# {'Techie': 2, 'Street Demon': 1, 'Divinicorp': 1, 'Executioner': 1, 'Golden Ox': 1, 'Soul Killer': 1}
# 755 und 815
# Unit auf Feld gesetzt!
# 3 und 7
# Champion(name=Neeko, cost=11, traits=['Street Demon', 'Strategist'], star_level=2, png=downloaded_images/Neeko.png)
# Neeko
# 32
# [Champion(name=Brand, cost=4, traits=['Street Demon', 'Techie'], star_level=1, png=downloaded_images/Brand.png), Champion(name=Neeko, cost=11, traits=['Street Demon', 'Strategist'], star_level=2, png=downloaded_images/Neeko.png), Champion(name=Vex, cost=4, traits=['Divinicorp', 'Executioner'], star_level=1, png=downloaded_images/Vex.png), Champion(name=Viego, cost=5, traits=['Golden Ox', 'Soul Killer', 'Techie'], star_level=1, png=downloaded_images/Viego.png), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# ('Brand', ('Street Demon', 'Techie'))
# ('Neeko', ('Strategist', 'Street Demon'))
# ('Vex', ('Divinicorp', 'Executioner'))
# ('Viego', ('Golden Ox', 'Soul Killer', 'Techie'))
# {'Street Demon': 2, 'Techie': 2, 'Strategist': 1, 'Divinicorp': 1, 'Executioner': 1, 'Golden Ox': 1, 'Soul Killer': 1}
# {'Street Demon': 2, 'Techie': 2, 'Strategist': 1, 'Divinicorp': 1, 'Executioner': 1, 'Golden Ox': 1, 'Soul Killer': 1}
